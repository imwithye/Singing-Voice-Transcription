# %%
import os
from effnet import SeqDataset
from utils import VALID_DATASET_DIR

idx = 401
feature_path = os.path.join(VALID_DATASET_DIR, str(idx), "CQT_feature.pt")
test_dataset = SeqDataset(feature_path, str(idx))

# %%
from utils import PROJECT_DIR

MODEL_PATH = os.path.join(PROJECT_DIR, "effnet", "models", "1005_e_4")
MODELS_SAVE_DIR = os.path.join(PROJECT_DIR, "models")

from effnet import EffNetPredictor
from utils import DEVICE

predictor = EffNetPredictor(device=DEVICE, model_path=MODEL_PATH)

results = predictor.predict(
    test_dataset,
    results={},
    onset_thres=0.4,
    offset_thres=0.5,
)
# Out:
# load
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       6 from effnet import EffNetPredictor
#       7 from utils import DEVICE
# ----> 9 predictor = EffNetPredictor(device=DEVICE, model_path=MODEL_PATH)
#      11 results = predictor.predict(
#      12     test_dataset,
#      13     results={},
#      14     onset_thres=0.4,
#      15     offset_thres=0.5,
#      16 )
#
# File ~/autodl-tmp/Singing-Voice-Transcription/effnet/predictor.py:27, in EffNetPredictor.__init__(self, device, model_path)
#      25 if model_path is not None:
#      26     print("load")
# ---> 27     self.model = EffNetb0().to(self.device)
#      28     self.model.load_state_dict(
#      29         torch.load(model_path, map_location=self.device), strict=False
#      30     )
#      31     print("Model read from {}.".format(model_path))
#
# ...
