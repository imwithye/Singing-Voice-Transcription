# %%
import os
from effnet import SeqDataset, EffNetPredictor
from utils import (
    DEVICE,
    PROJECT_DIR,
    VALID_DATASET_DIR,
    read_json,
    notes2mid,
    music21_from_midi,
)

idx = 401
correct = os.path.join(VALID_DATASET_DIR, str(idx), "Vocals.mid")
print("Correct: ")
s = music21_from_midi(correct)
s.show()
print("Predict: ")
predict = os.path.join(VALID_DATASET_DIR, str(idx), "Vocals_predict.mid")
s = music21_from_midi(predict)
s.show()
# Out:
# Correct:
# <p style="padding-top: 20px">&nbsp;</p>
# Predict:
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
